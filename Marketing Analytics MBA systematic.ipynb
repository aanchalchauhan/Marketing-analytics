# %%
import pandas as pd
mydata="C:/Users/Toshil/Desktop/Marketing/sales_data.csv"
mydata=pd.read_csv(mydata)
mydata
# Out:
#     OrderID      Product  Qnt  Price      State   Sales  Profit
# 0         1  Electronics    2  27079     Punjab   54158    8124
# 1         2     Clothing    2   2500        Goa    5000    8474
# 2         3     Computer    3  30835  Karnataka   92505   12951
# 3         4    Furniture    3  22013         MH   66039   10566
# 4         5  Electronics    7  24581  Karnataka  172067   30975
# 5         6     Computer   10  41561     Punjab  415610   62340
# 6         7     Clothing    2   2200  Karnataka    4400   11458
# 7         8     Computer    8  44135    Gujarat  353080   38840
# 8         9    Furniture    9  38662    Gujarat  347958   62631
# 9        10     Computer    2  33259     Punjab   66518    9312
# 10       11     Clothing    7   3000  Karnataka   21000   39382
# 11       12     Computer    3  48496     Punjab  145488   24732
# 12       13     Computer    6  45291        Goa  271746   51630
# 13       14  Electronics    8  47245         MH  377960   41576
# ...

# %%
#Determining the Dimension of the data
mydata.shape
# Out:
# (100, 7)

# %%
#Determining the Keys
mydata.keys()
# Out:
# Index(['OrderID', 'Product', 'Qnt', 'Price', 'State', 'Sales', 'Profit'], dtype='object')

# %%
#Printing the information of the dataset
print("Information of the dataset: \n",mydata.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
# OrderID    100 non-null int64
# Product    100 non-null object
# Qnt        100 non-null int64
# Price      100 non-null int64
# State      100 non-null object
# Sales      100 non-null int64
# Profit     100 non-null int64
# dtypes: int64(5), object(2)
# memory usage: 5.5+ KB
# Information of the dataset:
#  None

# %%
#Printing the Description of the dataset
print("Description of the dataset: \n")
mydata.describe
# Out:
# Description of the dataset:
# <bound method NDFrame.describe of     OrderID      Product  Qnt  Price      State   Sales  Profit
# 0         1  Electronics    2  27079     Punjab   54158    8124
# 1         2     Clothing    2   2500        Goa    5000    8474
# 2         3     Computer    3  30835  Karnataka   92505   12951
# 3         4    Furniture    3  22013         MH   66039   10566
# 4         5  Electronics    7  24581  Karnataka  172067   30975
# 5         6     Computer   10  41561     Punjab  415610   62340
# 6         7     Clothing    2   2200  Karnataka    4400   11458
# 7         8     Computer    8  44135    Gujarat  353080   38840
# 8         9    Furniture    9  38662    Gujarat  347958   62631
# 9        10     Computer    2  33259     Punjab   66518    9312
# 10       11     Clothing    7   3000  Karnataka   21000   39382
# 11       12     Computer    3  48496     Punjab  145488   24732
# 12       13     Computer    6  45291        Goa  271746   51630
# ...

# %%
#If we want to display the statestic behind of the continues variables:
print("Description of the dataset: \n")
mydata.describe()
# Out:
# Description of the dataset:
#           OrderID         Qnt        Price          Sales        Profit
# count  100.000000  100.000000    100.00000     100.000000    100.000000
# mean    50.500000    5.600000  30148.34000  170395.230000  29927.080000
# std     29.011492    2.835561  14566.13192  123439.065796  18016.599237
# min      1.000000    1.000000   1200.00000    2100.000000   2867.000000
# 25%     25.750000    3.000000  23564.00000   53090.000000  14883.750000
# 50%     50.500000    6.000000  33552.00000  167460.000000  28240.000000
# 75%     75.250000    8.000000  42318.00000  263252.250000  41835.750000
# max    100.000000   10.000000  49886.00000  445560.000000  74844.000000

# %%
#If we want to show only top 5 rows
mydata.head(5)
# Out:
#    OrderID      Product  Qnt  Price      State   Sales  Profit
# 0        1  Electronics    2  27079     Punjab   54158    8124
# 1        2     Clothing    2   2500        Goa    5000    8474
# 2        3     Computer    3  30835  Karnataka   92505   12951
# 3        4    Furniture    3  22013         MH   66039   10566
# 4        5  Electronics    7  24581  Karnataka  172067   30975

# %%
#If we want to show only bottom 5 rows
mydata.tail(5)
# Out:
#     OrderID      Product  Qnt  Price      State   Sales  Profit
# 95       96  Electronics    3  42268  Karnataka  126804   24093
# 96       97  Electronics    4  36189  Karnataka  144756   17372
# 97       98     Clothing    8   4800         MH   38400   62824
# 98       99     Clothing    6   1400    Gujarat    8400   20088
# 99      100         Auto    6  28250    Gujarat  169500   23730

# %%
#If we want to print the number of records of product column:
print("The number of records in product column:\n",mydata['Product'].value_counts())
# Out:
# The number of records in product column:
#  Electronics    29
# Computer       22
# Auto           18
# Clothing       16
# Furniture      15
# Name: Product, dtype: int64

# %%
#If we want to print the number of records of State column:
print("The number of records in State column:\n",mydata['State'].value_counts())
# Out:
# The number of records in product column:
#  Gujarat      25
# Karnataka    23
# MH           21
# Punjab       17
# Goa          14
# Name: State, dtype: int64

# %%
#If we want to do different operations in profit column:

print("Total Profit of the organization is:\n",mydata['Profit'].sum())
print("Mean of the Profit column is:\n",mydata['Profit'].mean())
print("Median of the Profit column is:\n",mydata['Profit'].median())
print("Max of the Profit column is:\n",mydata['Profit'].max())
print("Min of the Profit column is:\n",mydata['Profit'].min())
print("Count of the Profit column is:\n",mydata['Profit'].count())
print("Average of the Profit column is:\n",mydata['Profit'].sum()/[mydata['Profit'].count()])
# Out:
# Total Profit of the organization is:
#  2992708
# Mean of the Profit column is:
#  29927.08
# Median of the Profit column is:
#  28240.0
# Max of the Profit column is:
#  74844
# Min of the Profit column is:
#  2867
# Count of the Profit column is:
#  100
# Average of the Profit column is:
#  [29927.08]
